# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

from sklearn.cluster import KMeans

# %matplotlib inline

# %%
x = [16, 25, 18, 22, 5, 10, 21, 4, 30, 25]
y = [11, 7, 9, 16, 16, 15, 16, 7, 17, 5]

# %%
plt.scatter(x,y)
plt.show()

# %%
X = np.array([[16, 11],
              [25, 7],
              [18, 9],
              [22, 16],
              [5, 16],
              [10, 15],
              [21, 16],
              [4, 7],
              [30, 17],
              [25, 5]])

# %%
myGroups = KMeans(n_clusters=4)

myGroups.fit(X)

centroids = myGroups.cluster_centers_

labels = myGroups.labels_
print("cluster size k-means:{}".format(np.bincount(labels)))
# Out:
# cluster size k-means:[2 3 3 2]

# %%
colors = ["b.","g.","r.","c.","m."]

# 
for i in range(len(X)):
    plt.plot(X[i][0], X[i][1], colors[labels[i]], markersize = 10)

# 

plt.scatter(centroids[:, 0],centroids[:, 1], marker = "x", s=150, linewidths = 5)
plt.show()

# %%
from sklearn.metrics.cluster import silhouette_score
range_n_nclusters = [2, 3, 4, 5]
for num_clusters in range_n_nclusters:
        kmeans = KMeans (n_clusters=num_clusters, max_iter=50)
        kmeans.fit(X)
        cluster_labels =kmeans.labels_
        
        silhouette_avg = silhouette_score(X,cluster_labels )
        print ("for n_clusters={0}, the silhouette score is {1}".format(num_clusters,silhouette_avg ))
# Out:
# for n_clusters=2, the silhouette score is 0.47881429480762705
# for n_clusters=3, the silhouette score is 0.39123973587195665
# for n_clusters=4, the silhouette score is 0.41410695301889866
# for n_clusters=5, the silhouette score is 0.47735744360221244
